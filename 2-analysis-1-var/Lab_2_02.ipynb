# %% [markdown]
# # Lab 2.02 - Some theoretical questions

# %% [markdown]
# ## Exercise 1
#
# The following box plot shows data on the GPA of 500 students at a secondary school.
# GPA = Grade Point Average = average of your grades, usually used in higher education and in the United States.
#
# ![image.png](data:image/png;base64,...)
#
# 1. What is the range of GPAs in this dataset? Approximately 2.5
# 2. What is the median of the GPAs? 3
# 3. What is the interquartile range in this dataset? Approximately 1.15
# 4. Where is the mean in this dataset? We cannot extract the mean from just a box plot, but due that the lower whisker is bigger than the highest whisker, it is very possible that the mean lies lower than the median. The mean lies inside the range.
# 5. What percentage of students have a GPA that falls outside the actual box of the
# box plot? 50%, because the box lies between the interquartile range, that means, between the first quartile and the third quartile.
# 6. What percentage of students have a GPA
# below the median in this dataset? 50%, because the median is the value in the middle, the second quartile, the 50 percentile.

# %% [markdown]
# ## Exercise 2
#
# The heights of the first-year pupils are recorded. The mean, median, range and standard deviation are calculated.
# When analysing all the heights, the researcher discovers that, due to an oversight, the height of one of the teachers is also included in the measurements. She removes the teacher's height and recalculates the measures of central tendency and dispersion.
# What is the effect on
#
# * the mean: it will be lower, since the teacher's height was an outlier too big compared to the average height of first-year pupils.
# * the median: it won't have a significative difference compared to the earlier median, since we only removed one value, and the median will move only one height to the left.
# * the range: it will be way lower, since the teacher's height was an outlier, so it was very probably the maximum height of the sample.
# * the standard deviation: it will be way way lower, since the difference of the teacher's height to the mean was probably pretty big, and due to the mean being bigger than it should, the variance of the first-year's height was also bigger than it should be.
#
# Explain briefly in each case.

# %% [markdown]
# ## Exercise 3
#
# Three groups of 27 young people each record how much money they earn per week during the summer holidays. In each group, the mean = 250 EUR, the median = 250 EUR, the range = 400 EUR and the interquartile range = 300 EUR.
#
# ![image.png](data:image/png;base64,...)
#
# 1. In each group, the box plot of this data looks the same. Which box plot is that?
#
# ![image.png](data:image/png;base64,...)
# I would say C.
#
# 2. The standard deviations of the three groups are as follows:
# A. 127.67 = B
# B. 158.70 = A
# C. 171.59 = C
# Provide the correct standard deviation for each group.
#
# 3. Removing 250 euros from the data set changes the mode, but not the median and the mean. This statement is true for
# * Group 1
# * Group 2
# * Group 3
# Multiple answers may be correct. Group 2
#
# 4. Removing a value of 250 EUR from the dataset increases the standard deviation and variance. This statement is true for
# * Group 1
# * Group 2
# * Group 3
# Multiple answers may be correct. The increase is true for everyone.
#
# Source: Delta 3 - 5 uur Wiskunde

# %% [markdown]
# ## Exercise 4
#
# Combine each boxplot whit the matchting histogram. Explain.
#
# ![image.png](data:image/png;base64,...)
#
# Source: Delta 3 - 5 uur Wiskunde
